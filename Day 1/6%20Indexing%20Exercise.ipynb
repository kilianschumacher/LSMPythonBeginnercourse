# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Zooming into Time Signals
# Time series data is just a sequence of values!  Let's use indexing to visualize smaller parts of a time series!

# %% [markdown]
# #### Data Generation
# Run the following code to have Python create the data we'll analyze

# %%
np.random.seed(42)
data = np.sin(np.linspace(0, 1000*np.pi, 50000) * np.random.random() ) * np.random.random()
data += np.sin(np.linspace(0, 1000*np.pi, 50000) * np.random.random() ) * np.random.random()
data.shape
# Out:
# (50000,)

# %% [markdown]
# #### Data Plotting
# The **plt.plot()** function makes a plot.

# %%
plt.plot(data)

# %% [markdown]
# #### Exercises

# %% [markdown]
# There's too much data here for us to look at clearly!  Select just the first half of the data and plot it.

# %%
plt.plot(data[0:25000])

# %% [markdown]
# It looks like there's a Wave structure that repeats 8-9 times.  Select just one of these waves and plot it so we can see what that wave looks like!

# %%
plt.plot(data[0:2500])

# %% [markdown]
# There's a smaller wave inside the big wave! Zoom into one of those and plot it!

# %%
plt.plot(data[0:250])

# %% [markdown]
# ### Cropping Images
# Images are just 3D arrays of integers!  Let's load an image and visualize it onscreen using Matplotlib, a plotting library.  Working with images generally uses these 3 functions:
#
# | Function | Purpose  | Example |
# | :----:   | :----:   | :---:   |
# | plt.imread() | Loads a image from a filename  | plt.imread("brian.png" |
# | plt.imshow() | Plots a multidimensional array as an image | plt.imshow(my_image_array) |
# | plt.imsave() | Saves an array as an image on the computer | plt.imsave("new_image.jpg", my_array) |
#
# Let's **plt.imread()** function and do some cropping exercises on the image:

# %%
import matplotlib.pyplot as plt

image = plt.imread('cells.jpg')
image.shape
# Out:
# (170, 297, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
plt.imshow(image);

# %% [markdown]
# **Exercises:** Crop the image in the following ways using slicing, writing code like the following:
#
# ```python
# new_image = image[20:50, 50:100]
# plt.imshow(new_image)
# ```

# %% [markdown]
# 1.  Show only the left cluster of cells.

# %% [markdown]
# new_image = image[20:50, 50:100]
# plt.imshow(new_image)

# %%
new_image = image[:, 10:175]
plt.imshow(new_image)

# %% [markdown]
# 2. Show only the right cluster of cells.

# %%
new_image = image[:,175:-1]
plt.imshow(new_image)

# %% [markdown]
# 3. Show only the tiny bright spot in the right cluster.

# %%
bright_spot_image = new_image[50:60,88:100]
plt.imshow(bright_spot_image)

# %% [markdown]
# 4. Show just the empty part of the image in the lower-right hand side.

# %%
empty_image = new_image[100:,:]
plt.imshow(empty_image)
