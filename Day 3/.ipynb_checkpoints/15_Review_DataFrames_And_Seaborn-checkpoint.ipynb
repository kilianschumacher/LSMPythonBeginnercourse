# %% [markdown]
# # Data Analysis Project: "Stroke Risk Factors"

# %% [markdown]
# ## Download Data onto Your Computer
#
#
# https://www.kaggle.com/fedesoriano/stroke-prediction-dataset?select=healthcare-dataset-stroke-data.csv
#
# Look for the download button next to the data description (not the big one at the top of the screen), as shown below:

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Put the csv file into the same directory as your notebook.

# %% [markdown]
# ## Load Data into Pandas
#
# This isn't an Excel file, so `pd.read_excel()` won't be able to read it.  What `pd.read_` function will work?

# %%
pd.read_csv("healthcare-dataset-stroke-data.csv")
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
strokedata = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
strokedata
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %% [markdown]
# ## Describe the columns you are interested in
# What `unique` values are there, what are their `value_counts`, what are their `min`, `max`, `means`?  Do they have any missing data?  Maybe make a plot or two to help!

# %% [markdown]
# ### Column 1: "________"

# %%
strokedata["hypertension"].unique()
# Out:
# array([0, 1])

# %%
strokedata["hypertension"].mean()
# Out:
# 0.0974559686888454

# %% [markdown]
# ### Column 2: "________"

# %%
strokedata["work_type"].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
strokedata[["work_type", "age"]].value_counts()
# Out:
# work_type      age
# Private        57.0    67
# children       5.0     65
# Private        54.0    60
#                23.0    59
#                32.0    59
#                        ..
# Self-employed  25.0     1
#                16.0     1
#                13.0     1
#                7.0      1
# Govt_job       14.0     1
# Length: 254, dtype: int64

# %%
import seaborn as sns

# %%
sns.catplot(data=strokedata, x="work_type", y="age", kind="box", hue="gender")

# %% [markdown]
# ### Column 3: "________"

# %%
sns.catplot(data=strokedata, x="Residence_type", y="avg_glucose_level", kind="swarm", hue="gender")
# Out:
# /Users/kilianschumacher/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 62.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/kilianschumacher/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 61.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=strokedata, x="Residence_type", y="avg_glucose_level", kind="bar", hue="gender")

# %%
sns.catplot(data=strokedata, x="Residence_type", y="avg_glucose_level", kind="box", hue="gender")

# %%
adults = strokedata["age"] >= 18
adults
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5105    True
# 5106    True
# 5107    True
# 5108    True
# 5109    True
# Name: age, Length: 5110, dtype: bool

# %%
strokedata.df

# %%
sns.catplot(data=strokedata, x="ever_married", y="stroke", kind="bar", hue="gender")

# %% [markdown]
# ## Look for Relationships between the Columns: Plots
# Make some plots showing the relationships between the columns of interest. What conclusions can we make from this data?
#
# Useful functions: `sns.catplot()`, `sns.jointplot()`
#
# More ideas at the Seaborn Gallery: https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# ### Conclusion 1

# %%
#Average glucose levels tend to be the same in rural an urban areas

# %% [markdown]
# ### Conclusion 2

# %%
#Males appear to have slightly higher glucose levels than females

# %% [markdown]
# ## Save the Data as an Excel File
# Want to see the data in Excel?  Try:
#
# ```python
# df.to_excel("my_filename.xls", index=False)
# ```
