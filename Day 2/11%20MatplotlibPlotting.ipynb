# %%
# %matplotlib inline

# %%
import matplotlib

# %%
print(matplotlib.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
matplotlib.style.use('default')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercises: Make some attractive plots!

# %% [markdown]
# ### Make a Line Plot showing the following timeseries:

# %%
secs = np.sort(np.random.uniform(3, 100, size=100))
data1 = np.random.gamma(1.7, 1., size=100)
random3 = np.random.gamma(2.3, 1., size=100)

# %%
secs
# Out:
# array([ 3.61071405,  3.82683188,  6.90192669,  7.37684889,  7.75003576,
#         8.52951005,  9.53243561, 10.67082164, 11.17252035, 12.69213849,
#        13.25712736, 13.95139818, 14.15794156, 15.10660248, 15.33743396,
#        16.59001026, 16.8186465 , 16.97504487, 17.22120361, 18.40746839,
#        18.58970526, 19.50909002, 20.18535627, 21.42984511, 23.80289735,
#        24.04376528, 25.34858871, 29.57864119, 31.02430183, 31.51005944,
#        31.58894424, 32.75160137, 33.12243803, 33.5629781 , 33.75166826,
#        36.26702606, 36.76956794, 37.48580237, 37.58130974, 39.83455041,
#        40.24572157, 40.30286331, 41.17366265, 41.19078781, 41.28117924,
#        41.4611657 , 42.13290612, 42.15859812, 42.86199701, 43.15058501,
#        43.2296107 , 44.95485729, 45.36619269, 45.67707444, 46.48383771,
#        48.22872828, 49.12255865, 49.42949183, 50.43918439, 50.93567042,
#        51.46174012, 51.84108066, 52.63724844, 53.36519496, 53.38895413,
#        54.55278555, 56.894002  , 57.69221873, 57.73259061, 60.66961313,
#        61.78389111, 62.17515014, 62.60808573, 63.2422602 , 65.32291305,
#        68.32888032, 69.42195878, 71.6412566 , 73.18802467, 74.03691929,
#        75.13153574, 76.71043068, 78.11046735, 78.28675173, 81.55976638,
#        85.88390091, 85.88431853, 86.26273305, 86.31072036, 89.58252397,
#        90.1756991 , 90.57500455, 91.73047278, 93.0758857 , 93.23781814,
#        94.33333125, 96.82655474, 97.1871573 , 97.74370773, 98.56576215])

# %%
random3
# Out:
# array([2.87112729, 2.43784966, 1.63106555, 3.78410365, 3.87370985,
#        3.68236425, 1.70406915, 1.79608904, 0.47680198, 4.29396926,
#        0.45245057, 3.40733568, 2.33426943, 1.09031597, 1.76888937,
#        1.32272293, 2.00084644, 3.79874795, 5.98638096, 0.72779048,
#        2.48069409, 1.95987258, 2.50788352, 0.82632758, 3.65358076,
#        1.01949758, 2.59283648, 1.14967491, 0.58213109, 3.07571148,
#        1.75378557, 1.81299424, 2.2349371 , 0.6189913 , 3.3222615 ,
#        2.91493113, 1.4012921 , 1.90264882, 2.02366152, 4.19887753,
#        1.34014681, 3.36684441, 3.37449332, 1.83415928, 2.56324239,
#        0.70522154, 1.58712635, 3.66736463, 0.74452122, 1.68015589,
#        1.08282629, 1.78826974, 0.58344082, 5.04621757, 3.07512907,
#        1.47156772, 2.67523025, 5.5498603 , 3.08150137, 3.19802449,
#        4.11354747, 1.82254363, 1.87151463, 1.98281472, 1.90747864,
#        1.61424476, 2.51916648, 2.03762891, 1.36324236, 0.29235877,
#        1.19633615, 4.06187941, 2.13424775, 0.2950515 , 6.99528536,
#        0.71115828, 2.87209759, 1.4405537 , 0.73870952, 1.241078  ,
#        0.53863301, 4.2903837 , 2.54557682, 0.5111157 , 1.2039365 ,
#        3.42047893, 2.76016198, 6.25223706, 3.4458664 , 1.91218527,
#        2.3007887 , 1.18461277, 0.30839592, 1.56634526, 2.27211647,
#        2.58962941, 3.5558385 , 2.48316436, 4.48834544, 2.92985822])

# %% [markdown]
# ### Make a figure showing 3 different random distributions's pdfs and cdfs

# %%
plt.plot(secs,data1)

# %%
plt.plot(secs)

# %%
data=np.random.choice(5, size=100)
plt.hist(data);

# %%
data2=np.random.binomial(190,0.5, size=1000000000)
plt.hist(data2)

# %%
data=np.random.binomial

# %%
datagamma = np.random.gamma(1, 1., size=10000)
plt.hist(datagamma);
plt.title("This is a very nice title");
plt.xlabel("Hi my name is x")
plt.ylabel('And I am Y')
plt.xlim(0, 20);

# %% [markdown]
# ### Make a figure comparing
# $$ 2 ^ x $$
# against
# $$ x^2 $$.
#
# Where do they intersect?

# %%
x=np.arange(-5,5,.1)
x
plt.plot(x,x**2);
plt.plot(x,2**x, label="");
plt.title("This is a very nice title");
plt.xlabel("Hi my name is x")
plt.ylabel('And I am Y')
# Out:
# Text(0, 0.5, 'And I am Y')

# %% [markdown]
# ### Plot some noisy sinusoidal data as points, along with a line through the non-noisy wave

# %% [markdown]
# ### Exercise: "T-Test Simulator".  Use the starting code below to build interactions that change the mean and standard deviation of the dataset.
#
# *Note*: May need to install scipy and ipywidgets.  If Ipywidgets needs to be installed, then VSCode/JupyterLab will need to be restarted for the widgets to work.

# %%
#  !conda install -y ipywidgets

# %%
from ipywidgets import interact, IntSlider, Checkbox, FloatSlider
from scipy.stats import ttest_1samp

# %%
x = np.random.randn(100)

@interact(
    bins=IntSlider(10, 3, 100),
    cdf=Checkbox(),
)
def hist(bins, cdf):
    plt.figure(figsize=(2, 2))
    plt.hist(x, bins=bins, cumulative=cdf)
    t = ttest_1samp(x, 0)
    print(f"t={t.statistic:.2f}, p={t.pvalue:.3f}")
# Out:
# interactive(children=(IntSlider(value=10, description='bins', min=3), Checkbox(value=False, description='cdf')…
