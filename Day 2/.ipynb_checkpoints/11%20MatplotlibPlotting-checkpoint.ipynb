# %%
# %matplotlib inline

# %%
import matplotlib

# %%
print(matplotlib.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
matplotlib.style.use('default')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercises: Make some attractive plots!

# %% [markdown]
# ### Make a Line Plot showing the following timeseries:

# %%
secs = np.sort(np.random.uniform(3, 100, size=100))
data1 = np.random.gamma(1.7, 1., size=100)
random3 = np.random.gamma(2.3, 1., size=100)

# %%
secs
# Out:
# array([ 3.2030593 ,  4.14738686,  4.24512575,  5.34433749,  5.67437532,
#         6.93340999,  7.62285039, 10.82311934, 11.25776275, 12.45175491,
#        13.86172366, 13.93039476, 14.70928351, 15.06848011, 15.29079614,
#        15.9219838 , 16.10412652, 16.46043672, 16.67979143, 17.16838766,
#        17.62928397, 18.87933699, 19.39585564, 21.26777964, 23.20685878,
#        23.49915015, 26.48788279, 27.95031844, 28.1467144 , 28.19350755,
#        28.99966221, 29.11776077, 29.49321233, 30.80555613, 31.24119264,
#        33.29512792, 33.44816148, 36.00894651, 41.81862303, 42.00536507,
#        42.05308633, 43.57468081, 43.9961276 , 44.86428394, 46.55629457,
#        46.86952357, 48.49157474, 50.2839028 , 50.80504078, 51.27296615,
#        52.33041517, 52.61841   , 52.61973126, 55.56946157, 55.79255182,
#        56.16683342, 57.86712839, 58.56665652, 59.05240958, 59.47539999,
#        59.69868056, 60.88171303, 62.15575415, 62.91219933, 63.06829269,
#        63.93925065, 64.2497046 , 65.31420349, 65.53591222, 66.60088722,
#        67.32322016, 72.67705157, 74.76752652, 74.88091042, 76.0812353 ,
#        78.65837383, 78.73230195, 79.63328474, 80.3798943 , 80.82284719,
#        81.64060367, 82.1636074 , 82.50984192, 82.6813394 , 83.10005631,
#        83.38797006, 86.00596362, 88.01370485, 88.06670007, 88.51922646,
#        88.65310733, 89.7212267 , 90.46335116, 90.94623731, 92.13708372,
#        92.89093678, 94.66070895, 95.34128384, 97.22532564, 98.11670866])

# %%
random3
# Out:
# array([3.63838509, 1.21105996, 1.14472375, 4.40893201, 1.53444439,
#        1.72676073, 2.41616825, 1.74318864, 2.43377487, 3.32402382,
#        2.25902725, 0.64699373, 2.37831246, 2.27348269, 3.84377371,
#        2.20156617, 1.88855363, 3.41567579, 1.68827684, 2.53995229,
#        0.90840245, 1.47435993, 0.7553601 , 4.01078677, 2.33780932,
#        2.49500224, 2.23460527, 2.37742435, 0.6112422 , 0.38544843,
#        4.69575659, 2.52259018, 3.65348923, 2.03236015, 2.82488531,
#        9.11581145, 1.7943322 , 3.17178069, 1.51566071, 2.39956892,
#        2.03661121, 4.69835851, 2.53064223, 0.97768389, 0.40043447,
#        1.54532574, 0.84426606, 1.70629367, 2.86849351, 3.4801644 ,
#        2.22804422, 3.93736875, 1.97408745, 2.24321679, 2.50167652,
#        2.58835678, 3.63476823, 2.13312481, 1.60195681, 1.82923317,
#        2.89300673, 2.69727444, 3.88942528, 1.8968231 , 4.31597883,
#        0.69383858, 0.82803045, 1.05814418, 1.31262414, 0.76696527,
#        1.76434306, 6.38519568, 0.80400659, 3.69909979, 3.9923602 ,
#        1.122674  , 2.19568763, 4.05062834, 3.4023858 , 4.2430766 ,
#        4.99641873, 0.48957809, 0.45895324, 2.34199042, 1.20335168,
#        1.43646788, 0.13680827, 0.56721392, 3.35274769, 3.43633346,
#        2.06993993, 1.82347955, 4.21651987, 2.07604481, 5.31055558,
#        2.16002799, 3.83928322, 5.74112306, 2.39944363, 3.9007936 ])

# %% [markdown]
# ### Make a figure showing 3 different random distributions's pdfs and cdfs

# %%
plt.plot(secs,data1)

# %%
plt.plot(secs)

# %%
data=np.random.choice(5, size=100)
plt.hist(data);

# %%
data2=np.random.binomial(190,0.5, size=1000)
plt.hist(data2)
# Out:
# (array([  3.,  13.,  74., 122., 271., 291., 128.,  75.,  19.,   4.]),
#  array([ 71. ,  75.7,  80.4,  85.1,  89.8,  94.5,  99.2, 103.9, 108.6,
#         113.3, 118. ]),
#  <BarContainer object of 10 artists>)

# %%
data=np.random.binomial

# %%
datagamma = np.random.gamma(1, 1., size=100)
plt.hist(datagamma);
plt.title("This is a very nice title");
plt.xlabel("Hi my name is x")
plt.ylabel('And I am Y')
plt.xlim(0, 20);

# %% [markdown]
# ### Make a figure comparing
# $$ 2 ^ x $$
# against
# $$ x^2 $$.
#
# Where do they intersect?

# %%
x=np.arange(-5,5,.1)
x
plt.plot(x,x**2);
plt.plot(x,2**x, label="");
plt.title("This is a very nice title");
plt.xlabel("Hi my name is x")
plt.ylabel('And I am Y')
# Out:
# Text(0, 0.5, 'And I am Y')

# %% [markdown]
# ### Plot some noisy sinusoidal data as points, along with a line through the non-noisy wave

# %% [markdown]
# ### Exercise: "T-Test Simulator".  Use the starting code below to build interactions that change the mean and standard deviation of the dataset.
#
# *Note*: May need to install scipy and ipywidgets.  If Ipywidgets needs to be installed, then VSCode/JupyterLab will need to be restarted for the widgets to work.

# %%
#  !conda install -y ipywidgets

# %%
from ipywidgets import interact, IntSlider, Checkbox, FloatSlider
from scipy.stats import ttest_1samp

# %%
x = np.random.randn(100)

@interact(
    bins=IntSlider(10, 3, 100),
    cdf=Checkbox(),
)
def hist(bins, cdf):
    plt.figure(figsize=(2, 2))
    plt.hist(x, bins=bins, cumulative=cdf)
    t = ttest_1samp(x, 0)
    print(f"t={t.statistic:.2f}, p={t.pvalue:.3f}")
# Out:
# interactive(children=(IntSlider(value=10, description='bins', min=3), Checkbox(value=False, description='cdf')…
